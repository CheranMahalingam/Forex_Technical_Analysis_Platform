# %%
import numpy as np
import pandas as pd

# %%
ppi_data = pd.read_csv("../data/external/ppi/PPI_2018-2020.csv")
ppi_data[1880:1930]
# Out:
#        LOCATION INDICATOR   SUBJECT  MEASURE FREQUENCY     TIME  Value  \
# 1880  EU27_2020       PPI  DOMESTIC  IDX2015         M  2017-06  101.3
# 1881  EU27_2020       PPI  DOMESTIC  IDX2015         M  2017-07  101.3
# 1882  EU27_2020       PPI  DOMESTIC  IDX2015         M  2017-08  101.6
# 1883  EU27_2020       PPI  DOMESTIC  IDX2015         M  2017-09  102.0
# 1884  EU27_2020       PPI  DOMESTIC  IDX2015         M  2017-10  102.3
# 1885  EU27_2020       PPI  DOMESTIC  IDX2015         M  2017-11  102.6
# 1886  EU27_2020       PPI  DOMESTIC  IDX2015         M  2017-12  102.7
# 1887  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-01  103.2
# 1888  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-02  103.0
# 1889  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-03  103.2
# 1890  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-04  103.7
# 1891  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-05  104.5
# 1892  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-06  104.7
# 1893  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-07  104.8
# 1894  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-08  105.0
# 1895  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-09  105.3
# 1896  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-10  105.7
# 1897  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-11  105.2
# 1898  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-12  104.3
# 1899  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-01  104.4
# 1900  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-02  104.8
# 1901  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-03  105.0
# 1902  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-04  105.6
# 1903  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-05  105.8
# 1904  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-06  105.2
# 1905  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-07  105.3
# 1906  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-08  105.0
# 1907  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-09  105.2
# 1908  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-10  105.1
# 1909  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-11  105.1
# 1910  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-12  105.3
# 1911  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-01  105.6
# 1912  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-02  105.1
# 1913  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-03  103.7
# 1914  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-04  102.4
# 1915  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-05  102.2
# 1916  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-06  102.9
# 1917  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-07  103.3
# 1918  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-08  103.2
# 1919  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-09  103.0
# 1920  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-10  103.2
# 1921  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-11  103.4
#
#       Flag Codes
# 1880         NaN
# 1881         NaN
# 1882         NaN
# 1883         NaN
# 1884         NaN
# 1885         NaN
# 1886         NaN
# 1887         NaN
# 1888         NaN
# 1889         NaN
# 1890         NaN
# 1891         NaN
# 1892         NaN
# 1893         NaN
# 1894         NaN
# 1895         NaN
# 1896         NaN
# 1897         NaN
# 1898         NaN
# 1899         NaN
# 1900         NaN
# 1901         NaN
# 1902         NaN
# 1903         NaN
# 1904         NaN
# 1905         NaN
# 1906         NaN
# 1907         NaN
# 1908         NaN
# 1909         NaN
# 1910         NaN
# 1911         NaN
# 1912         NaN
# 1913         NaN
# 1914         NaN
# 1915         NaN
# 1916         NaN
# 1917         NaN
# 1918         NaN
# 1919         NaN
# 1920         NaN
# 1921         NaN

# %%
jpn_ppi = ppi_data[576:611]
jpn_ppi
# Out:
#     LOCATION INDICATOR   SUBJECT  MEASURE FREQUENCY     TIME  Value  \
# 576      JPN       PPI  DOMESTIC  IDX2015         M  2018-01  100.1
# 577      JPN       PPI  DOMESTIC  IDX2015         M  2018-02  100.1
# 578      JPN       PPI  DOMESTIC  IDX2015         M  2018-03  100.0
# 579      JPN       PPI  DOMESTIC  IDX2015         M  2018-04  100.3
# 580      JPN       PPI  DOMESTIC  IDX2015         M  2018-05  100.6
# 581      JPN       PPI  DOMESTIC  IDX2015         M  2018-06  100.9
# 582      JPN       PPI  DOMESTIC  IDX2015         M  2018-07  101.0
# 583      JPN       PPI  DOMESTIC  IDX2015         M  2018-08  101.0
# 584      JPN       PPI  DOMESTIC  IDX2015         M  2018-09  101.1
# 585      JPN       PPI  DOMESTIC  IDX2015         M  2018-10  101.7
# 586      JPN       PPI  DOMESTIC  IDX2015         M  2018-11  101.4
# 587      JPN       PPI  DOMESTIC  IDX2015         M  2018-12  100.7
# 588      JPN       PPI  DOMESTIC  IDX2015         M  2019-01  100.2
# 589      JPN       PPI  DOMESTIC  IDX2015         M  2019-02  100.4
# 590      JPN       PPI  DOMESTIC  IDX2015         M  2019-03  100.7
# 591      JPN       PPI  DOMESTIC  IDX2015         M  2019-04  101.1
# 592      JPN       PPI  DOMESTIC  IDX2015         M  2019-05  101.1
# 593      JPN       PPI  DOMESTIC  IDX2015         M  2019-06  100.7
# 594      JPN       PPI  DOMESTIC  IDX2015         M  2019-07  100.5
# 595      JPN       PPI  DOMESTIC  IDX2015         M  2019-08  100.3
# 596      JPN       PPI  DOMESTIC  IDX2015         M  2019-09  100.3
# 597      JPN       PPI  DOMESTIC  IDX2015         M  2019-10  101.8
# 598      JPN       PPI  DOMESTIC  IDX2015         M  2019-11  101.9
# 599      JPN       PPI  DOMESTIC  IDX2015         M  2019-12  102.0
# 600      JPN       PPI  DOMESTIC  IDX2015         M  2020-01  102.2
# 601      JPN       PPI  DOMESTIC  IDX2015         M  2020-02  101.8
# 602      JPN       PPI  DOMESTIC  IDX2015         M  2020-03  100.9
# 603      JPN       PPI  DOMESTIC  IDX2015         M  2020-04   99.1
# 604      JPN       PPI  DOMESTIC  IDX2015         M  2020-05   98.7
# 605      JPN       PPI  DOMESTIC  IDX2015         M  2020-06   99.3
# 606      JPN       PPI  DOMESTIC  IDX2015         M  2020-07   99.7
# 607      JPN       PPI  DOMESTIC  IDX2015         M  2020-08   99.9
# 608      JPN       PPI  DOMESTIC  IDX2015         M  2020-09   99.9
# 609      JPN       PPI  DOMESTIC  IDX2015         M  2020-10  100.0
# 610      JPN       PPI  DOMESTIC  IDX2015         M  2020-11  100.0
#
#      Flag Codes
# 576         NaN
# 577         NaN
# 578         NaN
# 579         NaN
# 580         NaN
# 581         NaN
# 582         NaN
# 583         NaN
# 584         NaN
# 585         NaN
# 586         NaN
# 587         NaN
# 588         NaN
# 589         NaN
# 590         NaN
# 591         NaN
# 592         NaN
# 593         NaN
# 594         NaN
# 595         NaN
# 596         NaN
# 597         NaN
# 598         NaN
# 599         NaN
# 600         NaN
# 601         NaN
# 602         NaN
# 603         NaN
# 604         NaN
# 605         NaN
# 606         NaN
# 607         NaN
# 608         NaN
# 609         NaN
# 610         NaN

# %%
chf_ppi = ppi_data[1093:1128]
chf_ppi
# Out:
#      LOCATION INDICATOR   SUBJECT  MEASURE FREQUENCY     TIME      Value  \
# 1093      CHE       PPI  DOMESTIC  IDX2015         M  2018-01   98.83909
# 1094      CHE       PPI  DOMESTIC  IDX2015         M  2018-02   98.83612
# 1095      CHE       PPI  DOMESTIC  IDX2015         M  2018-03   98.72445
# 1096      CHE       PPI  DOMESTIC  IDX2015         M  2018-04   99.04176
# 1097      CHE       PPI  DOMESTIC  IDX2015         M  2018-05   99.44859
# 1098      CHE       PPI  DOMESTIC  IDX2015         M  2018-06   99.82079
# 1099      CHE       PPI  DOMESTIC  IDX2015         M  2018-07   99.94275
# 1100      CHE       PPI  DOMESTIC  IDX2015         M  2018-08   99.96827
# 1101      CHE       PPI  DOMESTIC  IDX2015         M  2018-09  100.09790
# 1102      CHE       PPI  DOMESTIC  IDX2015         M  2018-10  100.45150
# 1103      CHE       PPI  DOMESTIC  IDX2015         M  2018-11  100.67640
# 1104      CHE       PPI  DOMESTIC  IDX2015         M  2018-12  100.42500
# 1105      CHE       PPI  DOMESTIC  IDX2015         M  2019-01   99.73958
# 1106      CHE       PPI  DOMESTIC  IDX2015         M  2019-02   99.96292
# 1107      CHE       PPI  DOMESTIC  IDX2015         M  2019-03  100.22660
# 1108      CHE       PPI  DOMESTIC  IDX2015         M  2019-04  100.29640
# 1109      CHE       PPI  DOMESTIC  IDX2015         M  2019-05  100.55850
# 1110      CHE       PPI  DOMESTIC  IDX2015         M  2019-06  100.27780
# 1111      CHE       PPI  DOMESTIC  IDX2015         M  2019-07  100.41250
# 1112      CHE       PPI  DOMESTIC  IDX2015         M  2019-08  100.38560
# 1113      CHE       PPI  DOMESTIC  IDX2015         M  2019-09  100.32910
# 1114      CHE       PPI  DOMESTIC  IDX2015         M  2019-10  100.40930
# 1115      CHE       PPI  DOMESTIC  IDX2015         M  2019-11  100.32640
# 1116      CHE       PPI  DOMESTIC  IDX2015         M  2019-12  100.40590
# 1117      CHE       PPI  DOMESTIC  IDX2015         M  2020-01  100.52750
# 1118      CHE       PPI  DOMESTIC  IDX2015         M  2020-02   99.99922
# 1119      CHE       PPI  DOMESTIC  IDX2015         M  2020-03   99.75758
# 1120      CHE       PPI  DOMESTIC  IDX2015         M  2020-04   99.18420
# 1121      CHE       PPI  DOMESTIC  IDX2015         M  2020-05   99.06016
# 1122      CHE       PPI  DOMESTIC  IDX2015         M  2020-06   99.37460
# 1123      CHE       PPI  DOMESTIC  IDX2015         M  2020-07   99.46886
# 1124      CHE       PPI  DOMESTIC  IDX2015         M  2020-08   99.55343
# 1125      CHE       PPI  DOMESTIC  IDX2015         M  2020-09   99.60210
# 1126      CHE       PPI  DOMESTIC  IDX2015         M  2020-10   99.68597
# 1127      CHE       PPI  DOMESTIC  IDX2015         M  2020-11   99.43889
#
#       Flag Codes
# 1093         NaN
# 1094         NaN
# 1095         NaN
# 1096         NaN
# 1097         NaN
# 1098         NaN
# 1099         NaN
# 1100         NaN
# 1101         NaN
# 1102         NaN
# 1103         NaN
# 1104         NaN
# 1105         NaN
# 1106         NaN
# 1107         NaN
# 1108         NaN
# 1109         NaN
# 1110         NaN
# 1111         NaN
# 1112         NaN
# 1113         NaN
# 1114         NaN
# 1115         NaN
# 1116         NaN
# 1117         NaN
# 1118         NaN
# 1119         NaN
# 1120         NaN
# 1121         NaN
# 1122         NaN
# 1123         NaN
# 1124         NaN
# 1125         NaN
# 1126         NaN
# 1127         NaN

# %%
gbp_ppi = ppi_data[1187:1222]
gbp_ppi
# Out:
#      LOCATION INDICATOR   SUBJECT  MEASURE FREQUENCY     TIME     Value  \
# 1187      GBR       PPI  DOMESTIC  IDX2015         M  2018-01  105.9912
# 1188      GBR       PPI  DOMESTIC  IDX2015         M  2018-02  105.9912
# 1189      GBR       PPI  DOMESTIC  IDX2015         M  2018-03  106.1912
# 1190      GBR       PPI  DOMESTIC  IDX2015         M  2018-04  106.6911
# 1191      GBR       PPI  DOMESTIC  IDX2015         M  2018-05  107.5910
# 1192      GBR       PPI  DOMESTIC  IDX2015         M  2018-06  108.0910
# 1193      GBR       PPI  DOMESTIC  IDX2015         M  2018-07  107.8910
# 1194      GBR       PPI  DOMESTIC  IDX2015         M  2018-08  108.2910
# 1195      GBR       PPI  DOMESTIC  IDX2015         M  2018-09  108.7909
# 1196      GBR       PPI  DOMESTIC  IDX2015         M  2018-10  109.1909
# 1197      GBR       PPI  DOMESTIC  IDX2015         M  2018-11  108.9909
# 1198      GBR       PPI  DOMESTIC  IDX2015         M  2018-12  108.3910
# 1199      GBR       PPI  DOMESTIC  IDX2015         M  2019-01  108.2910
# 1200      GBR       PPI  DOMESTIC  IDX2015         M  2019-02  108.4910
# 1201      GBR       PPI  DOMESTIC  IDX2015         M  2019-03  108.6909
# 1202      GBR       PPI  DOMESTIC  IDX2015         M  2019-04  109.1909
# 1203      GBR       PPI  DOMESTIC  IDX2015         M  2019-05  109.6909
# 1204      GBR       PPI  DOMESTIC  IDX2015         M  2019-06  109.5909
# 1205      GBR       PPI  DOMESTIC  IDX2015         M  2019-07  109.8908
# 1206      GBR       PPI  DOMESTIC  IDX2015         M  2019-08  109.7908
# 1207      GBR       PPI  DOMESTIC  IDX2015         M  2019-09  109.6909
# 1208      GBR       PPI  DOMESTIC  IDX2015         M  2019-10  109.3909
# 1209      GBR       PPI  DOMESTIC  IDX2015         M  2019-11  108.9909
# 1210      GBR       PPI  DOMESTIC  IDX2015         M  2019-12  108.9909
# 1211      GBR       PPI  DOMESTIC  IDX2015         M  2020-01  109.1909
# 1212      GBR       PPI  DOMESTIC  IDX2015         M  2020-02  108.9909
# 1213      GBR       PPI  DOMESTIC  IDX2015         M  2020-03  108.5910
# 1214      GBR       PPI  DOMESTIC  IDX2015         M  2020-04  107.3911
# 1215      GBR       PPI  DOMESTIC  IDX2015         M  2020-05  107.1911
# 1216      GBR       PPI  DOMESTIC  IDX2015         M  2020-06  107.7910
# 1217      GBR       PPI  DOMESTIC  IDX2015         M  2020-07  108.0910
# 1218      GBR       PPI  DOMESTIC  IDX2015         M  2020-08  107.9910
# 1219      GBR       PPI  DOMESTIC  IDX2015         M  2020-09  107.8910
# 1220      GBR       PPI  DOMESTIC  IDX2015         M  2020-10  107.8910
# 1221      GBR       PPI  DOMESTIC  IDX2015         M  2020-11  108.0910
#
#       Flag Codes
# 1187         NaN
# 1188         NaN
# 1189         NaN
# 1190         NaN
# 1191         NaN
# 1192         NaN
# 1193         NaN
# 1194         NaN
# 1195         NaN
# 1196         NaN
# 1197         NaN
# 1198         NaN
# 1199         NaN
# 1200         NaN
# 1201         NaN
# 1202         NaN
# 1203         NaN
# 1204         NaN
# 1205         NaN
# 1206         NaN
# 1207         NaN
# 1208         NaN
# 1209         NaN
# 1210         NaN
# 1211         NaN
# 1212         NaN
# 1213         NaN
# 1214         NaN
# 1215         NaN
# 1216         NaN
# 1217         NaN
# 1218         NaN
# 1219         NaN
# 1220         NaN
# 1221         NaN

# %%
eur_ppi = ppi_data[1887:1922]
eur_ppi
# Out:
#        LOCATION INDICATOR   SUBJECT  MEASURE FREQUENCY     TIME  Value  \
# 1887  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-01  103.2
# 1888  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-02  103.0
# 1889  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-03  103.2
# 1890  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-04  103.7
# 1891  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-05  104.5
# 1892  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-06  104.7
# 1893  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-07  104.8
# 1894  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-08  105.0
# 1895  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-09  105.3
# 1896  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-10  105.7
# 1897  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-11  105.2
# 1898  EU27_2020       PPI  DOMESTIC  IDX2015         M  2018-12  104.3
# 1899  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-01  104.4
# 1900  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-02  104.8
# 1901  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-03  105.0
# 1902  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-04  105.6
# 1903  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-05  105.8
# 1904  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-06  105.2
# 1905  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-07  105.3
# 1906  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-08  105.0
# 1907  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-09  105.2
# 1908  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-10  105.1
# 1909  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-11  105.1
# 1910  EU27_2020       PPI  DOMESTIC  IDX2015         M  2019-12  105.3
# 1911  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-01  105.6
# 1912  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-02  105.1
# 1913  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-03  103.7
# 1914  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-04  102.4
# 1915  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-05  102.2
# 1916  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-06  102.9
# 1917  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-07  103.3
# 1918  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-08  103.2
# 1919  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-09  103.0
# 1920  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-10  103.2
# 1921  EU27_2020       PPI  DOMESTIC  IDX2015         M  2020-11  103.4
#
#       Flag Codes
# 1887         NaN
# 1888         NaN
# 1889         NaN
# 1890         NaN
# 1891         NaN
# 1892         NaN
# 1893         NaN
# 1894         NaN
# 1895         NaN
# 1896         NaN
# 1897         NaN
# 1898         NaN
# 1899         NaN
# 1900         NaN
# 1901         NaN
# 1902         NaN
# 1903         NaN
# 1904         NaN
# 1905         NaN
# 1906         NaN
# 1907         NaN
# 1908         NaN
# 1909         NaN
# 1910         NaN
# 1911         NaN
# 1912         NaN
# 1913         NaN
# 1914         NaN
# 1915         NaN
# 1916         NaN
# 1917         NaN
# 1918         NaN
# 1919         NaN
# 1920         NaN
# 1921         NaN

# %%
eur_ppi = eur_ppi.rename(columns={"TIME": "Time", "Value": "PPI"})
gbp_ppi = gbp_ppi.rename(columns={"TIME": "Time", "Value": "PPI"})
jpn_ppi = jpn_ppi.rename(columns={"TIME": "Time", "Value": "PPI"})
chf_ppi = chf_ppi.rename(columns={"TIME": "Time", "Value": "PPI"})

# %%
eur_ppi = eur_ppi[{"Time", "PPI"}]
gbp_ppi = gbp_ppi[{"Time", "PPI"}]
jpn_ppi = jpn_ppi[{"Time", "PPI"}]
chf_ppi = chf_ppi[{"Time", "PPI"}]

# %%
import datetime
from datetime import datetime

def filled_dataframe(currency):
    time_array = pd.date_range(start="1/1/2018", freq="1H", periods=26304)
    ppi_array = np.zeros(26304)
    ppi_index = 0
    index = 0
    previous = 0
    for i in currency.iterrows():
        currency_datetime = datetime.strptime(i[1]["Time"], "%Y-%m")
        while index < 26304 and ppi_index < 26304 and time_array[index] < currency_datetime:
            ppi_array[ppi_index] = previous
            ppi_index += 1
            index += 1
        previous = i[1]["PPI"]
    while ppi_index < 26304:
        ppi_array[ppi_index] = currency["PPI"].iloc[-1]
        ppi_index += 1
    new_df = pd.DataFrame({"Time": time_array, "PPI": ppi_array})
    return new_df

filled_dataframe(eur_ppi)
# Out:
#                      Time    PPI
# 0     2018-01-01 00:00:00  103.2
# 1     2018-01-01 01:00:00  103.2
# 2     2018-01-01 02:00:00  103.2
# 3     2018-01-01 03:00:00  103.2
# 4     2018-01-01 04:00:00  103.2
# ...                   ...    ...
# 26299 2020-12-31 19:00:00  103.4
# 26300 2020-12-31 20:00:00  103.4
# 26301 2020-12-31 21:00:00  103.4
# 26302 2020-12-31 22:00:00  103.4
# 26303 2020-12-31 23:00:00  103.4
#
# [26304 rows x 2 columns]

# %%
eur_ppi_datetime = filled_dataframe(eur_ppi)
jpn_ppi_datetime = filled_dataframe(jpn_ppi)
chf_ppi_datetime = filled_dataframe(chf_ppi)
gbp_ppi_datetime = filled_dataframe(gbp_ppi)
gbp_ppi_datetime
# Out:
#                      Time       PPI
# 0     2018-01-01 00:00:00  105.9912
# 1     2018-01-01 01:00:00  105.9912
# 2     2018-01-01 02:00:00  105.9912
# 3     2018-01-01 03:00:00  105.9912
# 4     2018-01-01 04:00:00  105.9912
# ...                   ...       ...
# 26299 2020-12-31 19:00:00  108.0910
# 26300 2020-12-31 20:00:00  108.0910
# 26301 2020-12-31 21:00:00  108.0910
# 26302 2020-12-31 22:00:00  108.0910
# 26303 2020-12-31 23:00:00  108.0910
#
# [26304 rows x 2 columns]

# %%
cad_ppi = pd.read_csv("../data/external/ppi/CAD_PPI_2018-2020.csv")
cad_ppi = cad_ppi[232:243]

# %%
cad_ppi = cad_ppi.rename(columns={"DATE": "Time", "PIEAMP01CAQ661N": "PPI"})
cad_ppi
# Out:
#            Time         PPI
# 232  2018-01-01  105.130257
# 233  2018-04-01  107.548680
# 234  2018-07-01  107.797635
# 235  2018-10-01  106.979639
# 236  2019-01-01  106.375033
# 237  2019-04-01  107.690940
# 238  2019-07-01  106.375033
# 239  2019-10-01  106.517294
# 240  2020-01-01  106.303903
# 241  2020-04-01  104.170001
# 242  2020-07-01  106.659554

# %%
usd_ppi = pd.read_csv("../data/external/ppi/USD_PPI_2018-2020.csv")
usd_ppi = usd_ppi[232:243]
usd_ppi
# Out:
#            DATE  PIEAMP01USQ661N
# 232  2018-01-01       104.212701
# 233  2018-04-01       106.242702
# 234  2018-07-01       107.069074
# 235  2018-10-01       106.709782
# 236  2019-01-01       105.470224
# 237  2019-04-01       106.943322
# 238  2019-07-01       105.955268
# 239  2019-10-01       105.901374
# 240  2020-01-01       104.913321
# 241  2020-04-01       101.535974
# 242  2020-07-01       103.835444

# %%
usd_ppi = usd_ppi.rename(columns={"DATE": "Time", "PIEAMP01USQ661N": "PPI"})
usd_ppi
# Out:
#            Time         PPI
# 232  2018-01-01  104.212701
# 233  2018-04-01  106.242702
# 234  2018-07-01  107.069074
# 235  2018-10-01  106.709782
# 236  2019-01-01  105.470224
# 237  2019-04-01  106.943322
# 238  2019-07-01  105.955268
# 239  2019-10-01  105.901374
# 240  2020-01-01  104.913321
# 241  2020-04-01  101.535974
# 242  2020-07-01  103.835444

# %%
aud_ppi = pd.read_csv("../data/external/ppi/AUD_PPI_2018-2020.csv")
aud_ppi = aud_ppi[198:209]
aud_ppi
# Out:
#            DATE  PIEAMP01AUQ661N
# 198  2018-01-01       105.167027
# 199  2018-04-01       107.858688
# 200  2018-07-01       108.819995
# 201  2018-10-01       109.781303
# 202  2019-01-01       110.069695
# 203  2019-04-01       111.127133
# 204  2019-07-01       112.376832
# 205  2019-10-01       112.761355
# 206  2020-01-01       113.626532
# 207  2020-04-01       112.376832
# 208  2020-07-01       112.088440

# %%
aud_ppi = aud_ppi.rename(columns={"DATE": "Time", "PIEAMP01AUQ661N": "PPI"})
aud_ppi
# Out:
#            Time         PPI
# 198  2018-01-01  105.167027
# 199  2018-04-01  107.858688
# 200  2018-07-01  108.819995
# 201  2018-10-01  109.781303
# 202  2019-01-01  110.069695
# 203  2019-04-01  111.127133
# 204  2019-07-01  112.376832
# 205  2019-10-01  112.761355
# 206  2020-01-01  113.626532
# 207  2020-04-01  112.376832
# 208  2020-07-01  112.088440

# %%
nzd_ppi = pd.read_csv("../data/external/ppi/NZD_PPI_2018-2020.csv")
nzd_ppi = nzd_ppi[232:243]
nzd_ppi
# Out:
#            DATE  PIEAMP01NZQ661N
# 232  2018-01-01       106.973330
# 233  2018-04-01       109.615855
# 234  2018-07-01       112.747737
# 235  2018-10-01       111.377539
# 236  2019-01-01       108.343528
# 237  2019-04-01       111.377539
# 238  2019-07-01       113.824321
# 239  2019-10-01       114.117935
# 240  2020-01-01       113.432836
# 241  2020-04-01       113.237093
# 242  2020-07-01       108.832885

# %%
nzd_ppi = nzd_ppi.rename(columns={"DATE": "Time", "PIEAMP01NZQ661N": "PPI"})
nzd_ppi
# Out:
#            Time         PPI
# 232  2018-01-01  106.973330
# 233  2018-04-01  109.615855
# 234  2018-07-01  112.747737
# 235  2018-10-01  111.377539
# 236  2019-01-01  108.343528
# 237  2019-04-01  111.377539
# 238  2019-07-01  113.824321
# 239  2019-10-01  114.117935
# 240  2020-01-01  113.432836
# 241  2020-04-01  113.237093
# 242  2020-07-01  108.832885

# %%
def filled_dataframe_2(currency):
    time_array = pd.date_range(start="1/1/2018", freq="1H", periods=26304)
    ppi_array = np.zeros(26304)
    ppi_index = 0
    index = 0
    previous = 0
    for i in currency.iterrows():
        currency_datetime = datetime.strptime(i[1]["Time"], "%Y-%m-%d")
        while index < 26304 and ppi_index < 26304 and time_array[index] < currency_datetime:
            ppi_array[ppi_index] = previous
            ppi_index += 1
            index += 1
        previous = i[1]["PPI"]
    while ppi_index < 26304:
        ppi_array[ppi_index] = currency["PPI"].iloc[-1]
        ppi_index += 1
    new_df = pd.DataFrame({"Time": time_array, "PPI": ppi_array})
    return new_df

filled_dataframe_2(nzd_ppi)
# Out:
#                      Time         PPI
# 0     2018-01-01 00:00:00  106.973330
# 1     2018-01-01 01:00:00  106.973330
# 2     2018-01-01 02:00:00  106.973330
# 3     2018-01-01 03:00:00  106.973330
# 4     2018-01-01 04:00:00  106.973330
# ...                   ...         ...
# 26299 2020-12-31 19:00:00  108.832885
# 26300 2020-12-31 20:00:00  108.832885
# 26301 2020-12-31 21:00:00  108.832885
# 26302 2020-12-31 22:00:00  108.832885
# 26303 2020-12-31 23:00:00  108.832885
#
# [26304 rows x 2 columns]

# %%
nzd_ppi_datetime = filled_dataframe_2(nzd_ppi)
cad_ppi_datetime = filled_dataframe_2(cad_ppi)
usd_ppi_datetime = filled_dataframe_2(usd_ppi)
aud_ppi_datetime = filled_dataframe_2(aud_ppi)
aud_ppi_datetime
# Out:
#                      Time         PPI
# 0     2018-01-01 00:00:00  105.167027
# 1     2018-01-01 01:00:00  105.167027
# 2     2018-01-01 02:00:00  105.167027
# 3     2018-01-01 03:00:00  105.167027
# 4     2018-01-01 04:00:00  105.167027
# ...                   ...         ...
# 26299 2020-12-31 19:00:00  112.088440
# 26300 2020-12-31 20:00:00  112.088440
# 26301 2020-12-31 21:00:00  112.088440
# 26302 2020-12-31 22:00:00  112.088440
# 26303 2020-12-31 23:00:00  112.088440
#
# [26304 rows x 2 columns]
