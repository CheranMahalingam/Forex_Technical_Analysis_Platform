# %%
import numpy as np
import pandas as pd

# %%
unemployment_data = pd.read_csv("../data/external/unemployment/Unemployment_2018-2020.csv")
unemployment_data.tail(60)
# Out:
#        LOCATION INDICATOR SUBJECT MEASURE FREQUENCY     TIME     Value  \
# 1801        COL       HUR     TOT   PC_LF         M  2019-11  10.82743
# 1802        COL       HUR     TOT   PC_LF         M  2019-12  10.31656
# 1803        COL       HUR     TOT   PC_LF         M  2020-01  10.61920
# 1804        COL       HUR     TOT   PC_LF         M  2020-02  10.85050
# 1805        COL       HUR     TOT   PC_LF         M  2020-03  12.17435
# 1806        COL       HUR     TOT   PC_LF         M  2020-04  20.26320
# 1807        COL       HUR     TOT   PC_LF         M  2020-05  21.11611
# 1808        COL       HUR     TOT   PC_LF         M  2020-06  20.59773
# 1809        COL       HUR     TOT   PC_LF         M  2020-07  19.62779
# 1810        COL       HUR     TOT   PC_LF         M  2020-08  17.06232
# 1811        COL       HUR     TOT   PC_LF         M  2020-09  16.48711
# 1812        COL       HUR     TOT   PC_LF         M  2020-10  16.25519
# ...

# %%
aud_unemployment = unemployment_data[12:47]
aud_unemployment
# Out:
#    LOCATION INDICATOR SUBJECT MEASURE FREQUENCY     TIME     Value Flag Codes
# 12      AUS       HUR     TOT   PC_LF         M  2018-01  5.501085        NaN
# 13      AUS       HUR     TOT   PC_LF         M  2018-02  5.559339        NaN
# 14      AUS       HUR     TOT   PC_LF         M  2018-03  5.505105        NaN
# 15      AUS       HUR     TOT   PC_LF         M  2018-04  5.534267        NaN
# 16      AUS       HUR     TOT   PC_LF         M  2018-05  5.406442        NaN
# 17      AUS       HUR     TOT   PC_LF         M  2018-06  5.318580        NaN
# 18      AUS       HUR     TOT   PC_LF         M  2018-07  5.275815        NaN
# 19      AUS       HUR     TOT   PC_LF         M  2018-08  5.257135        NaN
# 20      AUS       HUR     TOT   PC_LF         M  2018-09  5.015530        NaN
# 21      AUS       HUR     TOT   PC_LF         M  2018-10  5.002687        NaN
# 22      AUS       HUR     TOT   PC_LF         M  2018-11  5.098609        NaN
# ...

# %%
cad_unemployment = unemployment_data[153:189]
cad_unemployment
# Out:
#     LOCATION INDICATOR SUBJECT MEASURE FREQUENCY     TIME  Value Flag Codes
# 153      CAN       HUR     TOT   PC_LF         M  2018-01    5.8        NaN
# 154      CAN       HUR     TOT   PC_LF         M  2018-02    5.8        NaN
# 155      CAN       HUR     TOT   PC_LF         M  2018-03    5.8        NaN
# 156      CAN       HUR     TOT   PC_LF         M  2018-04    5.9        NaN
# 157      CAN       HUR     TOT   PC_LF         M  2018-05    5.9        NaN
# 158      CAN       HUR     TOT   PC_LF         M  2018-06    6.0        NaN
# 159      CAN       HUR     TOT   PC_LF         M  2018-07    5.8        NaN
# 160      CAN       HUR     TOT   PC_LF         M  2018-08    6.0        NaN
# 161      CAN       HUR     TOT   PC_LF         M  2018-09    5.9        NaN
# 162      CAN       HUR     TOT   PC_LF         M  2018-10    5.8        NaN
# 163      CAN       HUR     TOT   PC_LF         M  2018-11    5.6        NaN
# ...

# %%
jpn_unemployment = unemployment_data[668:703]
jpn_unemployment
# Out:
#     LOCATION INDICATOR SUBJECT MEASURE FREQUENCY     TIME  Value Flag Codes
# 668      JPN       HUR     TOT   PC_LF         M  2018-01    2.4        NaN
# 669      JPN       HUR     TOT   PC_LF         M  2018-02    2.5        NaN
# 670      JPN       HUR     TOT   PC_LF         M  2018-03    2.5        NaN
# 671      JPN       HUR     TOT   PC_LF         M  2018-04    2.5        NaN
# 672      JPN       HUR     TOT   PC_LF         M  2018-05    2.3        NaN
# 673      JPN       HUR     TOT   PC_LF         M  2018-06    2.5        NaN
# 674      JPN       HUR     TOT   PC_LF         M  2018-07    2.5        NaN
# 675      JPN       HUR     TOT   PC_LF         M  2018-08    2.5        NaN
# 676      JPN       HUR     TOT   PC_LF         M  2018-09    2.3        NaN
# 677      JPN       HUR     TOT   PC_LF         M  2018-10    2.4        NaN
# 678      JPN       HUR     TOT   PC_LF         M  2018-11    2.5        NaN
# ...

# %%
gbp_unemployment = unemployment_data[1228:1261]
gbp_unemployment
# Out:
#      LOCATION INDICATOR SUBJECT MEASURE FREQUENCY     TIME  Value Flag Codes
# 1228      GBR       HUR     TOT   PC_LF         M  2018-01    4.2        NaN
# 1229      GBR       HUR     TOT   PC_LF         M  2018-02    4.2        NaN
# 1230      GBR       HUR     TOT   PC_LF         M  2018-03    4.2        NaN
# 1231      GBR       HUR     TOT   PC_LF         M  2018-04    4.0        NaN
# 1232      GBR       HUR     TOT   PC_LF         M  2018-05    3.9        NaN
# 1233      GBR       HUR     TOT   PC_LF         M  2018-06    4.0        NaN
# 1234      GBR       HUR     TOT   PC_LF         M  2018-07    4.0        NaN
# 1235      GBR       HUR     TOT   PC_LF         M  2018-08    4.0        NaN
# 1236      GBR       HUR     TOT   PC_LF         M  2018-09    4.0        NaN
# 1237      GBR       HUR     TOT   PC_LF         M  2018-10    4.0        NaN
# 1238      GBR       HUR     TOT   PC_LF         M  2018-11    3.9        NaN
# ...

# %%
usd_unemployment = unemployment_data[1273:1309]
usd_unemployment
# Out:
#      LOCATION INDICATOR SUBJECT MEASURE FREQUENCY     TIME  Value Flag Codes
# 1273      USA       HUR     TOT   PC_LF         M  2018-01    4.0        NaN
# 1274      USA       HUR     TOT   PC_LF         M  2018-02    4.1        NaN
# 1275      USA       HUR     TOT   PC_LF         M  2018-03    4.0        NaN
# 1276      USA       HUR     TOT   PC_LF         M  2018-04    4.0        NaN
# 1277      USA       HUR     TOT   PC_LF         M  2018-05    3.8        NaN
# 1278      USA       HUR     TOT   PC_LF         M  2018-06    4.0        NaN
# 1279      USA       HUR     TOT   PC_LF         M  2018-07    3.8        NaN
# 1280      USA       HUR     TOT   PC_LF         M  2018-08    3.8        NaN
# 1281      USA       HUR     TOT   PC_LF         M  2018-09    3.7        NaN
# 1282      USA       HUR     TOT   PC_LF         M  2018-10    3.8        NaN
# 1283      USA       HUR     TOT   PC_LF         M  2018-11    3.8        NaN
# ...

# %%
eur_unemployment = unemployment_data[1826:1861]
eur_unemployment
# Out:
#        LOCATION INDICATOR SUBJECT MEASURE FREQUENCY     TIME  Value Flag Codes
# 1826  EU27_2020       HUR     TOT   PC_LF         M  2018-01    7.7        NaN
# 1827  EU27_2020       HUR     TOT   PC_LF         M  2018-02    7.6        NaN
# 1828  EU27_2020       HUR     TOT   PC_LF         M  2018-03    7.5        NaN
# 1829  EU27_2020       HUR     TOT   PC_LF         M  2018-04    7.4        NaN
# 1830  EU27_2020       HUR     TOT   PC_LF         M  2018-05    7.3        NaN
# 1831  EU27_2020       HUR     TOT   PC_LF         M  2018-06    7.3        NaN
# 1832  EU27_2020       HUR     TOT   PC_LF         M  2018-07    7.2        NaN
# 1833  EU27_2020       HUR     TOT   PC_LF         M  2018-08    7.2        NaN
# 1834  EU27_2020       HUR     TOT   PC_LF         M  2018-09    7.1        NaN
# 1835  EU27_2020       HUR     TOT   PC_LF         M  2018-10    7.1        NaN
# 1836  EU27_2020       HUR     TOT   PC_LF         M  2018-11    7.1        NaN
# ...

# %%
eur_unemployment = eur_unemployment.rename(columns={"TIME": "Time", "Value": "Unemployment Rate"})
cad_unemployment = cad_unemployment.rename(columns={"TIME": "Time", "Value": "Unemployment Rate"})
usd_unemployment = usd_unemployment.rename(columns={"TIME": "Time", "Value": "Unemployment Rate"})
aud_unemployment = aud_unemployment.rename(columns={"TIME": "Time", "Value": "Unemployment Rate"})
jpn_unemployment = jpn_unemployment.rename(columns={"TIME": "Time", "Value": "Unemployment Rate"})
gbp_unemployment = gbp_unemployment.rename(columns={"TIME": "Time", "Value": "Unemployment Rate"})

# %%
aud_unemployment = aud_unemployment[{"Time", "Unemployment Rate"}]
usd_unemployment = usd_unemployment[{"Time", "Unemployment Rate"}]
cad_unemployment = cad_unemployment[{"Time", "Unemployment Rate"}]
eur_unemployment = eur_unemployment[{"Time", "Unemployment Rate"}]
jpn_unemployment = jpn_unemployment[{"Time", "Unemployment Rate"}]
gbp_unemployment = gbp_unemployment[{"Time", "Unemployment Rate"}]
gbp_unemployment
# Out:
#       Unemployment Rate     Time
# 1228                4.2  2018-01
# 1229                4.2  2018-02
# 1230                4.2  2018-03
# 1231                4.0  2018-04
# 1232                3.9  2018-05
# 1233                4.0  2018-06
# 1234                4.0  2018-07
# 1235                4.0  2018-08
# 1236                4.0  2018-09
# 1237                4.0  2018-10
# 1238                3.9  2018-11
# 1239                3.8  2018-12
# 1240                3.8  2019-01
# 1241                3.7  2019-02
# 1242                3.7  2019-03
# 1243                3.7  2019-04
# 1244                3.8  2019-05
# 1245                3.8  2019-06
# 1246                3.8  2019-07
# 1247                3.8  2019-08
# 1248                3.7  2019-09
# 1249                3.7  2019-10
# 1250                3.7  2019-11
# 1251                3.7  2019-12
# 1252                3.9  2020-01
# 1253                3.9  2020-02
# 1254                3.9  2020-03
# ...

# %%
import datetime
from datetime import datetime

def filled_dataframe(currency):
    time_array = pd.date_range(start="1/1/2018", freq="1H", periods=26304)
    un_array = np.zeros(26304)
    un_index = 0
    index = 0
    previous = 0
    for i in currency.iterrows():
        currency_datetime = datetime.strptime(i[1]["Time"], "%Y-%m")
        while index < 26304 and un_index < 26304 and time_array[index] < currency_datetime:
            un_array[un_index] = previous
            un_index += 1
            index += 1
        previous = i[1]["Unemployment Rate"]
    while un_index < 26304:
        un_array[un_index] = currency["Unemployment Rate"].iloc[-1]
        un_index += 1
    new_df = pd.DataFrame({"Time": time_array, "Unemployment Rate": un_array})
    return new_df

filled_dataframe(gbp_unemployment)
# Out:
#                      Time  Unemployment Rate
# 0     2018-01-01 00:00:00                4.2
# 1     2018-01-01 01:00:00                4.2
# 2     2018-01-01 02:00:00                4.2
# 3     2018-01-01 03:00:00                4.2
# 4     2018-01-01 04:00:00                4.2
# ...                   ...                ...
# 26299 2020-12-31 19:00:00                4.9
# 26300 2020-12-31 20:00:00                4.9
# 26301 2020-12-31 21:00:00                4.9
# 26302 2020-12-31 22:00:00                4.9
# 26303 2020-12-31 23:00:00                4.9
#
# [26304 rows x 2 columns]

# %%
aud_un_datetime = filled_dataframe(aud_unemployment)
cad_un_datetime = filled_dataframe(cad_unemployment)
usd_un_datetime = filled_dataframe(usd_unemployment)
gbp_un_datetime = filled_dataframe(gbp_unemployment)
eur_un_datetime = filled_dataframe(eur_unemployment)
jpn_un_datetime = filled_dataframe(jpn_unemployment)

# %%
nzd_data = pd.read_csv("../data/external/unemployment/NZD_Unemployment_2018-2020.csv")

# %%
nzd_unemployment = nzd_data[128:139]
nzd_unemployment
# Out:
#            DATE  LRUNTTTTNZQ156S
# 128  2018-01-01              4.4
# 129  2018-04-01              4.5
# 130  2018-07-01              4.0
# 131  2018-10-01              4.4
# 132  2019-01-01              4.2
# 133  2019-04-01              4.0
# 134  2019-07-01              4.2
# 135  2019-10-01              4.1
# 136  2020-01-01              4.2
# 137  2020-04-01              4.0
# 138  2020-07-01              5.3

# %%
chf_data = pd.read_csv("../data/external/unemployment/CHF_Unemployment_2018-2020.csv")
chf_unemployment = chf_data[75:86]
chf_unemployment
# Out:
#           DATE   LRUNTTTTCHQ156S
# 75  2018-01-01  4.87919814864613
# 76  2018-04-01  4.93191156738036
# 77  2018-07-01  4.24885264491719
# 78  2018-10-01  4.79203981756143
# 79  2019-01-01  4.63351956527248
# 80  2019-04-01  4.46711057130612
# 81  2019-07-01  4.39985498168033
# 82  2019-10-01  4.07800544341144
# 83  2020-01-01  4.22411014022817
# 84  2020-04-01  4.91597235698642
# 85  2020-07-01  5.04910434459102

# %%
chf_unemployment = chf_unemployment.rename(columns={"DATE": "Time", "LRUNTTTTCHQ156S": "Unemployment Rate"})

# %%
nzd_unemployment = nzd_unemployment.rename(columns={"DATE": "Time", "LRUNTTTTNZQ156S": "Unemployment Rate"})

# %%
nzd_unemployment
# Out:
#            Time  Unemployment Rate
# 128  2018-01-01                4.4
# 129  2018-04-01                4.5
# 130  2018-07-01                4.0
# 131  2018-10-01                4.4
# 132  2019-01-01                4.2
# 133  2019-04-01                4.0
# 134  2019-07-01                4.2
# 135  2019-10-01                4.1
# 136  2020-01-01                4.2
# 137  2020-04-01                4.0
# 138  2020-07-01                5.3

# %%
def filled_dataframe_2(currency):
    time_array = pd.date_range(start="1/1/2018", freq="1H", periods=26304)
    un_array = np.zeros(26304)
    un_index = 0
    index = 0
    previous = 0
    for i in currency.iterrows():
        currency_datetime = datetime.strptime(i[1]["Time"], "%Y-%m-%d")
        while index < 26304 and un_index < 26304 and time_array[index] < currency_datetime:
            un_array[un_index] = previous
            un_index += 1
            index += 1
        previous = i[1]["Unemployment Rate"]
    while un_index < 26304:
        un_array[un_index] = currency["Unemployment Rate"].iloc[-1]
        un_index += 1
    new_df = pd.DataFrame({"Time": time_array, "Unemployment Rate": un_array})
    return new_df

filled_dataframe_2(nzd_unemployment)
# Out:
#                      Time  Unemployment Rate
# 0     2018-01-01 00:00:00                4.4
# 1     2018-01-01 01:00:00                4.4
# 2     2018-01-01 02:00:00                4.4
# 3     2018-01-01 03:00:00                4.4
# 4     2018-01-01 04:00:00                4.4
# ...                   ...                ...
# 26299 2020-12-31 19:00:00                5.3
# 26300 2020-12-31 20:00:00                5.3
# 26301 2020-12-31 21:00:00                5.3
# 26302 2020-12-31 22:00:00                5.3
# 26303 2020-12-31 23:00:00                5.3
#
# [26304 rows x 2 columns]

# %%
nzd_un_datetime = filled_dataframe_2(nzd_unemployment)
chf_un_datetime = filled_dataframe_2(chf_unemployment)
chf_un_datetime
# Out:
#                      Time  Unemployment Rate
# 0     2018-01-01 00:00:00           4.879198
# 1     2018-01-01 01:00:00           4.879198
# 2     2018-01-01 02:00:00           4.879198
# 3     2018-01-01 03:00:00           4.879198
# 4     2018-01-01 04:00:00           4.879198
# ...                   ...                ...
# 26299 2020-12-31 19:00:00           5.049104
# 26300 2020-12-31 20:00:00           5.049104
# 26301 2020-12-31 21:00:00           5.049104
# 26302 2020-12-31 22:00:00           5.049104
# 26303 2020-12-31 23:00:00           5.049104
#
# [26304 rows x 2 columns]
